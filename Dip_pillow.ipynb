# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan-Karim/AI-ML/blob/main/Dip_pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
naltar = np.array(Image.open('/content/IMG_20230709_123632.jpg'))
plt.figure(figsize=(5,5))
plt.imshow(naltar)
plt.show()

# %%
gb = naltar

# %%
plt.figure(figsize=(10,10))
plt.subplot(131)
plt.imshow(gb)
plt.title("Gilgit-Baltistan")
plt.subplot(132)
plt.imshow(naltar)
plt.title("naltar")
plt.show()

# %%
array = np.array(naltar)
width, height, C = array.shape
print('width', width ,'height and Channel', height, C)
array
# Out:
# width 4608 height and Channel 3456 3
# array([[[164, 176, 190],
#         [159, 171, 185],
#         [163, 175, 189],
#         ...,
#         [240, 247, 255],
#         [239, 246, 254],
#         [239, 246, 254]],
#
#        [[161, 173, 187],
#         [159, 171, 185],
#         [164, 176, 190],
#         ...,
#         [239, 246, 254],
#         [239, 246, 254],
#         [239, 246, 254]],
#
#        [[158, 170, 184],
#         [158, 170, 184],
#         [163, 175, 189],
#         ...,
#         [239, 246, 254],
#         [238, 245, 253],
#         [237, 244, 252]],
#
#        ...,
#
#        [[150, 136,  99],
#         [157, 143, 106],
#         [166, 150, 114],
#         ...,
#         [107, 116, 111],
#         [101, 110, 105],
#         [ 99, 108, 103]],
#
#        [[167, 153, 116],
#         [172, 156, 120],
#         [176, 160, 124],
#         ...,
#         [106, 115, 110],
#         [105, 114, 109],
#         [106, 115, 110]],
#
#        [[179, 165, 128],
# ...

# %%
array_flip = np.zeros((width, height, C), dtype=np.uint8)

# %%
for i,row in enumerate(array):
    array_flip[width - 1 - i, :, :] = row

# %%
plt.imshow(array_flip)

# %%
from PIL import ImageOps

# %%
left = 50
right = 100
image = Image.open("/content/IMG_20230709_123632.jpg")
crop_image = image.crop((left, upper, right, lower))
plt.figure(figsize=(5,5))
plt.imshow(crop_image)
plt.show()
